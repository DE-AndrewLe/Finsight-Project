# %% [markdown]
# Import thư viện

# %%
from vnstock import *

# %% [markdown]
# MỤC TIÊU: lấy số liệu của 4 cổ acb, gmd, mbb, vix từ tháng 5-2020 tới hiện tại

# %% [markdown]
# Giá khớp lệnh

# %%
price_board('ACB,GMD,MBB,VIX')
# Out:
#   Mã CP      Giá  KLBD/TB5D  T.độ GD  KLGD ròng(CM)  %KLGD ròng (CM)  \
# 0   ACB  27150.0       1.38     0.68          86100             20.2
# 1   GMD  79300.0       0.72     0.44              0              0.0
# 2   MBB  23750.0       0.39     0.37        -110100            -20.8
# 3   VIX  19150.0       0.82     0.80        -312800            -18.4
#
#          RSI  MACD Hist MACD Signal Tín hiệu KT  ... Khớp nhiều nhất  \
# 0  44.476317      -0.14     Neutral     Neutral  ...           27000
# 1  55.505041      -0.31     Neutral         Buy  ...           78500
# 2  46.425948      -0.18     Neutral        Sell  ...           23750
# 3  44.615604      -0.25        Sell         Buy  ...           19150
#
#    Đ.góp VNINDEX  %Giá - %VNI (1M)  %Giá - %VNI (1Y)  VNINDEX P/E  \
# 0           0.05              -0.7              11.9      15.4727
# 1           0.02               0.0              37.5      15.4727
# 2          -0.07              -0.1              33.2      15.4727
# ...

# %% [markdown]
# Historical data

# %%
stock_historical_data("GMD", "2020-05-01", "2024-04-12")
# Out:
#            time   open   high    low  close   volume ticker
# 0    2020-05-04  16410  16410  15660  15880   404050    GMD
# 1    2020-05-05  15880  15880  15570  15880   199960    GMD
# 2    2020-05-06  15880  16059  15710  15880   371930    GMD
# 3    2020-05-07  16110  16320  15840  16149   424580    GMD
# 4    2020-05-08  16110  16370  16010  16059   413560    GMD
# ..          ...    ...    ...    ...    ...      ...    ...
# 985  2024-04-05  79300  79600  78000  78000  1262500    GMD
# 986  2024-04-08  78100  78700  77000  77500   909200    GMD
# 987  2024-04-09  78300  78600  77400  78600   649700    GMD
# 988  2024-04-10  78700  79900  78300  79000   901800    GMD
# 989  2024-04-11  77500  79300  77500  79300   644300    GMD
#
# [990 rows x 7 columns]

# %%
stock_historical_data("MBB", "2020-05-01", "2024-04-12")
# Out:
#            time   open   high    low  close    volume ticker
# 0    2020-05-04   7280   7320   7230   7230   2266940    MBB
# 1    2020-05-05   7250   7280   7140   7210   2512680    MBB
# 2    2020-05-06   7250   7300   7170   7280   3827470    MBB
# 3    2020-05-07   7280   7460   7280   7430   6237880    MBB
# 4    2020-05-08   7480   7760   7480   7570  12648540    MBB
# ..          ...    ...    ...    ...    ...       ...    ...
# 985  2024-04-05  23550  23750  23300  23350  25376700    MBB
# 986  2024-04-08  23400  23800  23150  23500  24714800    MBB
# 987  2024-04-09  23500  24000  23400  24000  15734800    MBB
# 988  2024-04-10  24300  24350  23800  23800  21078100    MBB
# 989  2024-04-11  23500  23850  23400  23750   9011600    MBB
#
# [990 rows x 7 columns]

# %%
stock_historical_data("VIX", "2020-05-01", "2024-04-12")
# Out:
#            time   open   high    low  close    volume ticker
# 0    2020-05-04   1700   1730   1660   1730     14310    VIX
# 1    2020-05-05   1700   1700   1660   1660     13100    VIX
# 2    2020-05-06   1660   1700   1660   1700      8406    VIX
# 3    2020-05-07   1660   1700   1660   1700     34504    VIX
# 4    2020-05-08   1700   1730   1700   1700     26519    VIX
# ..          ...    ...    ...    ...    ...       ...    ...
# 978  2024-04-05  19800  19850  19300  19300  51517300    VIX
# 979  2024-04-08  19450  19450  18950  18950  33944100    VIX
# 980  2024-04-09  19100  19650  18950  19650  27604300    VIX
# 981  2024-04-10  19650  19650  19200  19200  17468800    VIX
# 982  2024-04-11  18950  19350  18900  19150  26483000    VIX
#
# [983 rows x 7 columns]

# %%
stock_historical_data("ACB", "2020-05-01", "2024-04-12")
# Out:
#            time   open   high    low  close    volume ticker
# 0    2020-05-04   8430   8430   8270   8340   1193939    ACB
# 1    2020-05-05   8310   8390   8310   8340   1126770    ACB
# 2    2020-05-06   8390   8720   8310   8550   4453036    ACB
# 3    2020-05-07   8600   8720   8550   8720   2973997    ACB
# 4    2020-05-08   8760   9000   8640   8800   5995918    ACB
# ..          ...    ...    ...    ...    ...       ...    ...
# 980  2024-04-05  27300  27400  27100  27150  12289500    ACB
# 981  2024-04-08  27150  27250  26950  27150   6869300    ACB
# 982  2024-04-09  27150  27300  27050  27300   5371500    ACB
# 983  2024-04-10  27450  27600  27100  27100   5122000    ACB
# 984  2024-04-11  27000  27150  26900  27150  11286500    ACB
#
# [985 rows x 7 columns]

# %% [markdown]
# Intraday Trading Data

# %%
stock_intraday_data(symbol='GMD',  
                            page_size=5000)
# Out:
#     ticker      time  orderType investorType  volume  averagePrice  \
# 0      GMD  14:29:54     Buy Up        SHEEP   200.0       79100.0
# 1      GMD  14:29:53     Buy Up        SHEEP  1000.0       79000.0
# 2      GMD  14:29:24     Buy Up        SHEEP   100.0       79100.0
# 3      GMD  14:27:51     Buy Up        SHEEP  1000.0       79100.0
# 4      GMD  14:27:47     Buy Up         WOLF  4000.0       79040.0
# ..     ...       ...        ...          ...     ...           ...
# 389    GMD  09:16:24  Sell Down        SHEEP   600.0       77600.0
# 390    GMD  09:15:52  Sell Down        SHEEP  1000.0       77720.0
# 391    GMD  09:15:37  Sell Down        SHEEP   200.0       77700.0
# 392    GMD  09:15:34  Sell Down        SHEEP   100.0       77900.0
# 393    GMD  09:15:04  Sell Down        SHEEP   100.0       77500.0
#
#      orderCount  prevPriceChange
# 0           1.0            100.0
# 1           1.0           -100.0
# 2           1.0              0.0
# ...

# %%
stock_intraday_data(symbol='ACB', 
                            page_size=5000)
# Out:
#      ticker      time  orderType investorType    volume  averagePrice  \
# 0       ACB  14:29:46     Buy Up        SHEEP    1900.0       27100.0
# 1       ACB  14:29:27  Sell Down        SHEEP     200.0       27050.0
# 2       ACB  14:28:48  Sell Down        SHEEP     200.0       27050.0
# 3       ACB  14:28:37     Buy Up        SHEEP     300.0       27100.0
# 4       ACB  14:28:10  Sell Down         WOLF   15000.0       27050.0
# ...     ...       ...        ...          ...       ...           ...
# 1319    ACB  09:15:29  Sell Down        SHARK  100000.0       27000.0
# 1320    ACB  09:15:24     Buy Up        SHEEP     600.0       27050.0
# 1321    ACB  09:15:13     Buy Up        SHEEP     100.0       27050.0
# 1322    ACB  09:15:09  Sell Down        SHEEP     100.0       27000.0
# 1323    ACB  09:15:03  Sell Down        SHEEP    5700.0       27000.0
#
#       orderCount  prevPriceChange
# 0            1.0             50.0
# 1            1.0              0.0
# ...

# %%
stock_intraday_data(symbol='MBB', 
                            page_size=5000)
# Out:
#      ticker      time  orderType investorType   volume  averagePrice  \
# 0       MBB  14:29:59     Buy Up        SHEEP    100.0       23800.0
# 1       MBB  14:29:55  Sell Down        SHEEP    200.0       23750.0
# 2       MBB  14:29:51  Sell Down        SHEEP   7000.0       23750.0
# 3       MBB  14:29:51     Buy Up        SHEEP    400.0       23800.0
# 4       MBB  14:29:48     Buy Up        SHEEP   5000.0       23800.0
# ...     ...       ...        ...          ...      ...           ...
# 1927    MBB  09:15:05     Buy Up        SHEEP    300.0       23600.0
# 1928    MBB  09:15:04     Buy Up        SHEEP    100.0       23600.0
# 1929    MBB  09:15:03  Sell Down        SHARK  54500.0       23410.0
# 1930    MBB  09:15:03     Buy Up         WOLF  10800.0       23450.0
# 1931    MBB  09:15:03  Sell Down         WOLF  39700.0       23470.0
#
#       orderCount  prevPriceChange
# 0            1.0             50.0
# 1            1.0              0.0
# ...

# %%
stock_intraday_data(symbol='VIX', 
                            page_size=5000)
# Out:
#      ticker      time  orderType investorType   volume  averagePrice  \
# 0       VIX  14:29:54  Sell Down        SHEEP   3000.0       19150.0
# 1       VIX  14:29:53     Buy Up        SHEEP    300.0       19200.0
# 2       VIX  14:29:53  Sell Down         WOLF  20500.0       19150.0
# 3       VIX  14:29:38     Buy Up        SHEEP    300.0       19200.0
# 4       VIX  14:29:35  Sell Down        SHEEP    600.0       19150.0
# ...     ...       ...        ...          ...      ...           ...
# 3080    VIX  09:15:06     Buy Up        SHEEP   1000.0       18950.0
# 3081    VIX  09:15:04  Sell Down         WOLF  34000.0       18900.0
# 3082    VIX  09:15:04     Buy Up        SHEEP   1000.0       18950.0
# 3083    VIX  09:15:04  Sell Down        SHEEP   6300.0       18900.0
# 3084    VIX  09:15:03     Buy Up        SHEEP   1500.0       18950.0
#
#       orderCount  prevPriceChange
# 0            1.0            -50.0
# 1            1.0             50.0
# ...

# %% [markdown]
# Report from TCBS

# %%
financial_ratio("MBB", 'quarterly', True)
# Out:
# range                   Q4-2023 Q3-2023 Q2-2023 Q1-2023 Q4-2022 Q3-2022  \
# ticker                      MBB     MBB     MBB     MBB     MBB     MBB
# quarter                      Q4      Q3      Q2      Q1      Q4      Q3
# year                       2023    2023    2023    2023    2022    2022
# priceToEarning              6.1     5.1     5.1     4.6     4.4     5.1
# priceToBook                 1.3     1.1     1.1     1.0     1.0     1.2
# roe                       0.245   0.239   0.243   0.248   0.258   0.273
# roa                       0.025   0.026   0.025   0.025   0.026   0.029
# earningPerShare            3910    3617    3448    3396    3306    3324
# bookValuePerShare         18291   17356   16279   16032   15058   14357
# interestMargin            0.048   0.055   0.055   0.056   0.057   0.058
# nonInterestOnToi           0.22   0.187    0.18   0.143   0.181   0.177
# badDebtPercentage         0.016   0.019   0.014   0.018   0.011    0.01
# ...

# %%
financial_ratio("GMD", 'quarterly', True)
# Out:
# range                   Q4-2023 Q3-2023 Q2-2023 Q1-2023 Q4-2022 Q3-2022  \
# ticker                      GMD     GMD     GMD     GMD     GMD     GMD
# quarter                      Q4      Q3      Q2      Q1      Q4      Q3
# year                       2023    2023    2023    2023    2022    2022
# priceToEarning             11.1     9.0     6.8    16.8    13.7    14.2
# priceToBook                 2.9     2.4     1.8     2.2     2.0     2.0
# valueBeforeEbitda          17.6    14.4    12.9    12.5    12.2    12.6
# roe                       0.287   0.295   0.294   0.135    0.15   0.153
# roa                       0.166   0.184    0.18   0.076   0.083   0.092
# daysReceivable               39      68      84     -58     -57     -18
# daysInventory                13      13      13      13      12      11
# daysPayable                 120      83      76     110      97      65
# ebitOnInterest              4.0     8.7    16.0     8.2     7.4     8.5
# ...

# %%
financial_ratio("VIX", 'quarterly', True)
# Out:
# range                    Q4-2023  Q3-2023  Q2-2023  Q1-2023  Q4-2022  Q3-2022  \
# ticker                       VIX      VIX      VIX      VIX      VIX      VIX
# quarter                       Q4       Q3       Q2       Q1       Q4       Q3
# year                        2023     2023     2023     2023     2022     2022
# priceToEarning              13.3     15.7     12.9     82.5     12.1      9.9
# priceToBook                  1.5      1.2      0.9      0.6      0.5      0.7
# valueBeforeEbitda            8.9     11.4     14.5    138.7      5.9      3.4
# roe                        0.116    0.081    0.067    0.009    0.054    0.112
# roa                        0.112    0.079    0.066    0.008    0.048    0.103
# daysReceivable            1876.0   2021.0   2238.0   2225.0   1859.0   1560.0
# daysInventory                NaN      NaN      NaN      NaN      NaN      NaN
# daysPayable                174.0      NaN     14.0     47.0     64.0      NaN
# ...

# %%
financial_ratio("ACB", 'quarterly', True)
# Out:
# range                   Q4-2023 Q3-2023 Q2-2023 Q1-2023 Q4-2022 Q3-2022  \
# ticker                      ACB     ACB     ACB     ACB     ACB     ACB
# quarter                      Q4      Q3      Q2      Q1      Q4      Q3
# year                       2023    2023    2023    2023    2022    2022
# priceToEarning              6.6     5.7     5.9     5.6     5.2     5.4
# priceToBook                 1.5     1.3     1.4     1.3     1.2     1.3
# roe                       0.248   0.243   0.252   0.263   0.265    0.27
# roa                       0.024   0.025   0.025   0.026   0.024   0.025
# earningPerShare            4130    3838    3722    3742    3524    3410
# bookValuePerShare         18268   17205   16185   16099   15045   14349
# interestMargin            0.039   0.043   0.044   0.044   0.043   0.043
# nonInterestOnToi          0.249   0.263   0.222   0.215   0.186   0.149
# badDebtPercentage         0.012   0.012   0.011    0.01   0.007    0.01
# ...

# %% [markdown]
# Company Overview

# %%
company_overview('ACB')
# Out:
#   ticker exchange   industry companyType  noShareholders  foreignPercent  \
# 0    ACB     HOSE  Ngân hàng          NH           44011             0.3
#
#    outstandingShare  issueShare establishedYear  noEmployees  stockRating  \
# 0            3884.1      3884.1            None        13655          3.1
#
#    deltaInWeek  deltaInMonth  deltaInYear shortName industryEn  industryID  \
# 0       -0.007        -0.005        0.119       ACB      Banks         289
#
#   industryIDv2                 website
# 0         8355  https://www.acb.com.vn

# %%
company_overview('GMD')
# Out:
#   ticker exchange                    industry companyType  noShareholders  \
# 0    GMD     HOSE  Hàng & Dịch vụ Công nghiệp          CT           12179
#
#    foreignPercent  outstandingShare  issueShare establishedYear  noEmployees  \
# 0            0.49             310.5       305.9            1993         1522
#
#    stockRating  deltaInWeek  deltaInMonth  deltaInYear shortName  \
# 0          3.2        0.002         0.004        0.392  Gemadept
#
#                     industryEn  industryID industryIDv2  \
# 0  Industrial Goods & Services         193         2777
#
#                       website
# 0  http://www.gemadept.com.vn

# %%
company_overview('MBB')
# Out:
#   ticker exchange   industry companyType  noShareholders  foreignPercent  \
# 0    MBB     HOSE  Ngân hàng          NH          126621           0.232
#
#    outstandingShare  issueShare establishedYear  noEmployees  stockRating  \
# 0            5287.1      5214.1            1994        16085          3.4
#
#    deltaInWeek  deltaInMonth  deltaInYear shortName industryEn  industryID  \
# 0        0.006        -0.002        0.324    MBBank      Banks         289
#
#   industryIDv2                    website
# 0         8355  https://www.mbbank.com.vn

# %%
company_overview('VIX')
# Out:
#   ticker exchange           industry companyType  noShareholders  \
# 0    VIX     HOSE  Dịch vụ tài chính          CK            1703
#
#    foreignPercent  outstandingShare  issueShare establishedYear  noEmployees  \
# 0           0.084             669.4       669.4            2007           53
#
#    stockRating  deltaInWeek  deltaInMonth  deltaInYear        shortName  \
# 0          3.1       -0.039        -0.024        1.521  Chứng khoán VIX
#
#            industryEn  industryID industryIDv2              website
# 0  Financial Services         300         8777  https://www.vixs.vn

# %% [markdown]
# STOCK LIST ANALYSIS

# %%
stock_ls_analysis("ACB, MBB, VIX, GMD")
# Out:
# Mã CP                            MBB     ACB    GMD    VIX
# Vốn hóa (tỷ)                  125568  105452  24622  12820
# Giá                            23750   27150  79300  19150
# Số phiên tăng/giảm liên tiếp      -2       1      3     -2
# P/E                              6.1     6.6   11.1   13.3
# PEG                              0.3     0.4    0.1    0.1
# P/B                              1.3     1.5    2.9    1.5
# Cổ tức                           0.0     0.0    0.0    0.0
# ROE                            0.245   0.248  0.287  0.116
# ROA                            0.025   0.024  0.166  0.112
# Nợ/Vốn CSH                       8.8     9.1    0.2    0.0
# LNST 5 năm                     0.276   0.256   0.04  0.349
# Doanh thu 5 năm                0.193   0.185  0.073  0.291
# LNST quý gần nhất             -0.136  -0.008 -0.548  -0.04
# Doanh thu quý gần nhất        -0.026  -0.005  0.036  0.056
# LNST năm tới                   0.122    0.09  1.288  0.016
# ...

# %% [markdown]
# DIVIDEND HISTORICAL DATA

# %%
dividend_history("ACB")
# Out:
#    exerciseDate  cashYear  cashDividendPercentage issueMethod
# 0      01/06/23      2022                   0.100        cash
# 1      01/06/23      2023                   0.150       share
# 2      02/06/22      2022                   0.250       share
# 3      10/06/21      2021                   0.250       share
# 4      20/08/20      2020                   0.300       share
# 5      25/07/19      2019                   0.300       share
# 6      06/09/18      2018                   0.150       share
# 7      20/03/18      2018                   0.100       share
# 8      01/12/16      2017                   0.100       share
# 9      15/05/15      2014                   0.070        cash
# 10     13/05/14      2013                   0.070        cash
# 11     17/05/13      2012                   0.069        cash
# 12     30/03/12      2012                   0.100       share
# 13     03/01/12      2011                   0.200        cash
# ...

# %%
dividend_history("GMD")
# Out:
#    exerciseDate  cashYear  cashDividendPercentage issueMethod
# 0      21/09/23      2022                    0.20        cash
# 1      07/10/22      2021                    0.12        cash
# 2      13/08/21      2020                    0.12        cash
# 3      03/09/20      2019                    0.10        cash
# 4      05/11/19      2018                    0.15        cash
# 5      17/09/18      2017                    0.15        cash
# 6      09/03/18      2016                    0.15        cash
# 7      09/03/18      2018                    0.65        cash
# 8      27/05/16      2015                    0.20        cash
# 9      12/11/15      2014                    0.20        cash
# 10     11/12/14      2013                    0.12        cash
# 11     26/11/13      2012                    0.10        cash
# 12     03/04/12      2010                    0.06        cash
# 13     15/12/09      2009                    0.15        cash
# ...

# %%
dividend_history("VIX")
# Out:
#    exerciseDate  cashYear  cashDividendPercentage issueMethod
# 0      25/05/23      2023                    0.05       share
# 1      26/08/22      2022                    0.06       share
# 2      19/07/22      2021                    0.06        cash
# 3      07/09/21      2021                    0.15       share
# 4      09/07/20      2020                    0.10       share
# 5      23/05/19      2019                    0.15       share
# 6      22/05/18      2017                    0.05        cash
# 7      22/05/18      2018                    0.10       share
# 8      08/06/17      2017                    0.05       share
# 9      09/06/16      2016                    0.05       share
# 10     09/06/16      2015                    0.05        cash
# 11     22/09/15      2015                    0.10       share
# 12     25/04/12      2011                    0.10        cash

# %%
dividend_history("MBB")
# Out:
#    exerciseDate  cashYear  cashDividendPercentage issueMethod
# 0      14/07/23      2023                    0.15       share
# 1      14/06/23      2022                    0.05        cash
# 2      22/08/22      2022                    0.20       share
# 3      12/07/21      2021                    0.35       share
# 4      05/10/20      2020                    0.15       share
# 5      18/09/19      2019                    0.08       share
# 6      05/04/19      2018                    0.06        cash
# 7      06/07/18      2018                    0.05       share
# 8      17/01/18      2017                    0.06        cash
# 9      29/09/17      2017                    0.05       share
# 10     23/02/17      2016                    0.06        cash
# 11     24/10/16      2016                    0.05       share
# 12     15/09/15      2015                    0.05        cash
# 13     17/08/15      2015                    0.03       share
# ...

# %% [markdown]
# FINANCIAL REPORT

# %%
financial_report (symbol='ACB', report_type='BalanceSheet', frequency='Quarterly')
# Out:
#                                              CHỈ TIÊU       Q2 2020  \
# 0                                        TỔNG TÀI SẢN  3.967604e+14
# 1                          Tiền mặt, vàng bạc, đá quý  5.518509e+12
# 2            Tiền gửi tại Ngân hàng nhà nước Việt Nam  2.081391e+13
# 3   Tiền gửi tại các TCTD khác và cho vay các TCTD...  2.507038e+13
# 4                              Chứng khoán kinh doanh  6.359580e+11
# 5                              Chứng khoán kinh doanh  7.769950e+11
# 6            Dự phòng giảm giá chứng khoán kinh doanh -1.410370e+11
# 7   Các công cụ tài chính phái sinh và các tài sản...  1.290090e+11
# 8                                  Cho vay khách hàng  2.809903e+14
# 9                                  Cho vay khách hàng  2.837550e+14
# 10                 Dự phòng rủi ro cho vay khách hàng -2.764744e+12
# 11                                 Chứng khoán đầu tư  5.412946e+13
# 12                 Chứng khoán đầu tư sẵn sàng để bán  1.113984e+13
# ...

# %%
financial_report (symbol='GMD', report_type='BalanceSheet', frequency='Quarterly')
# Out:
#                                CHỈ TIÊU       Q2 2020       Q3 2020  \
# 0                          TỔNG TÀI SẢN  1.007545e+13  9.829561e+12
# 1                      TÀI SẢN NGẮN HẠN  1.385457e+12  1.267587e+12
# 2              Tiền và tương đương tiền  2.201280e+11  2.414184e+11
# 3                                  Tiền  2.136280e+11  2.229184e+11
# 4            Các khoản tương đương tiền  6.500000e+09  1.850000e+10
# ..                                  ...           ...           ...
# 113     Lợi ích cổ đông không kiểm soát  7.068751e+11  6.939968e+11
# 114  Vốn Ngân sách nhà nước và quỹ khác  0.000000e+00  0.000000e+00
# 116              Vốn ngân sách nhà nước  0.000000e+00  0.000000e+00
# 117   Nguồn kinh phí đã hình thành TSCĐ  0.000000e+00  0.000000e+00
# 119                 TỔNG CỘNG NGUỒN VỐN  1.007545e+13  9.829561e+12
#
#           Q4 2020       Q1 2021       Q2 2021       Q3 2021       Q4 2021  \
# 0    9.857526e+12  1.002574e+13  1.023434e+13  9.914648e+12  1.073754e+13
# ...

# %%
financial_report (symbol='MBB', report_type='BalanceSheet', frequency='Quarterly')
# Out:
#                                              CHỈ TIÊU       Q2 2020  \
# 0                                        TỔNG TÀI SẢN  4.216357e+14
# 1                          Tiền mặt, vàng bạc, đá quý  2.509108e+12
# 2            Tiền gửi tại Ngân hàng nhà nước Việt Nam  9.173365e+12
# 3   Tiền gửi tại các TCTD khác và cho vay các TCTD...  3.920238e+13
# 4                              Chứng khoán kinh doanh  1.518915e+12
# 5                              Chứng khoán kinh doanh  1.549447e+12
# 6            Dự phòng giảm giá chứng khoán kinh doanh -3.053200e+10
# 7   Các công cụ tài chính phái sinh và các tài sản...  0.000000e+00
# 8                                  Cho vay khách hàng  2.570547e+14
# 9                                  Cho vay khách hàng  2.613845e+14
# 10                 Dự phòng rủi ro cho vay khách hàng -4.329801e+12
# 11                                 Chứng khoán đầu tư  8.788706e+13
# 12                 Chứng khoán đầu tư sẵn sàng để bán  8.598727e+13
# ...

# %%
financial_report (symbol='VIX', report_type='BalanceSheet', frequency='Quarterly')
# Out:
#                                       CHỈ TIÊU       Q2 2020       Q3 2020  \
# 0                            TỔNG CỘNG TÀI SẢN  1.775984e+12  1.931665e+12
# 1                             TÀI SẢN NGẮN HẠN  1.737369e+12  1.891821e+12
# 2                   Tài sản tài chính ngắn hạn  1.735674e+12  1.890252e+12
# 3                    Tiền và tương đương tiền   1.521712e+11  1.904524e+11
# 4                                         Tiền  1.521712e+11  1.904524e+11
# ..                                         ...           ...           ...
# 155                   Vốn ngân sách nhà nước    0.000000e+00  0.000000e+00
# 156          Nguồn kinh phí đã hình thành TSCĐ  0.000000e+00  0.000000e+00
# 157  LỢI ÍCH CỦA CỔ ĐÔNG THIỂU SỐ (trước 2015)  0.000000e+00  0.000000e+00
# 158                        TỔNG CỘNG NGUỒN VỐN  1.775984e+12  1.931665e+12
# 159      LỢI NHUẬN ĐÃ PHÂN PHỐI CHO NHÀ ĐẦU TƯ  0.000000e+00  0.000000e+00
#
# ...

# %% [markdown]
# REPORT FROM TCBS

# %%
financial_flow(symbol="ACB", report_type='incomestatement', report_range='quarterly')
# Out:
#         ticker  revenue  yearRevenueGrowth  quarterRevenueGrowth  \
# index
# 2023-Q4    ACB     6290             -0.026                 0.013
# 2023-Q3    ACB     6209              0.029                -0.006
# 2023-Q2    ACB     6246              0.114                 0.005
# 2023-Q1    ACB     6215              0.142                -0.037
# 2022-Q4    ACB     6454              0.346                 0.070
# ...        ...      ...                ...                   ...
# 2007-Q4    ACB      369              0.954                 0.158
# 2007-Q3    ACB      318                NaN                -0.318
# 2007-Q2    ACB      467                NaN                 0.131
# 2007-Q1    ACB      413                NaN                 1.189
# 2006-Q4    ACB      189                NaN                   NaN
#
#         costOfGoodSold grossProfit  operationExpense  operationProfit  \
# index
# 2023-Q4           None        None             -3013             8378
# ...

# %%
financial_flow(symbol="MBB", report_type='incomestatement', report_range='quarterly')
# Out:
#         ticker  revenue  yearRevenueGrowth  quarterRevenueGrowth  \
# index
# 2023-Q4    MBB     9163             -0.048                -0.066
# 2023-Q3    MBB     9812              0.086                 0.035
# 2023-Q2    MBB     9481              0.057                -0.073
# 2023-Q1    MBB    10227              0.220                 0.062
# 2022-Q4    MBB     9630              0.343                 0.065
# 2022-Q3    MBB     9039              0.387                 0.008
# 2022-Q2    MBB     8969              0.367                 0.070
# 2022-Q1    MBB     8385              0.409                 0.170
# 2021-Q4    MBB     7170              0.237                 0.100
# 2021-Q3    MBB     6515              0.261                -0.007
# 2021-Q2    MBB     6563              0.419                 0.103
# 2021-Q1    MBB     5952              0.268                 0.027
# 2020-Q4    MBB     5794              0.185                 0.122
# ...

# %%
financial_flow(symbol="GMD", report_type='incomestatement', report_range='quarterly')
# Out:
#         ticker  revenue  yearRevenueGrowth  quarterRevenueGrowth  \
# index
# 2023-Q4    GMD     1034             -0.030                 0.036
# 2023-Q3    GMD      998              0.006                 0.094
# 2023-Q2    GMD      912             -0.067                 0.011
# 2023-Q1    GMD      902              0.025                -0.154
# 2022-Q4    GMD     1066              0.027                 0.075
# ...        ...      ...                ...                   ...
# 2006-Q1    GMD        0                NaN                   NaN
# 2005-Q4    GMD        0                NaN                   NaN
# 2005-Q3    GMD        0                NaN                   NaN
# 2005-Q2    GMD        0                NaN                   NaN
# 2005-Q1    GMD        0                NaN                   NaN
#
#          costOfGoodSold  grossProfit  operationExpense  operationProfit  \
# index
# 2023-Q4            -608          426              -276              150
# ...

# %%
financial_flow(symbol="VIX", report_type='incomestatement', report_range='quarterly')
# Out:
#         ticker  revenue  yearRevenueGrowth  quarterRevenueGrowth  \
# index
# 2023-Q4    VIX      341              0.438                 0.056
# 2023-Q3    VIX      323              0.772                -0.530
# 2023-Q2    VIX      688              1.138                 1.528
# 2023-Q1    VIX      272             -0.390                 0.147
# 2022-Q4    VIX      237             -0.243                 0.301
# 2022-Q3    VIX      182             -0.531                -0.433
# 2022-Q2    VIX      322             -0.097                -0.279
# 2022-Q1    VIX      446             -0.127                 0.424
# 2021-Q4    VIX      313              0.386                -0.195
# 2021-Q3    VIX      389              0.686                 0.092
# 2021-Q2    VIX      356              1.129                -0.303
# 2021-Q1    VIX      511              4.418                 1.260
# 2020-Q4    VIX      226              0.737                -0.021
# ...

# %% [markdown]
# Financial Health Rating

# %%
financial_health_rating("ACB")
# Out:
#   industryEn  loanDeposit  badLoanGrossLoan  badLoanAsset  provisionBadLoan  \
# 0      Banks            2                 4             5                 4
#
#   ticker  financialHealth netDebtEquity currentRatio quickRatio  \
# 0    ACB              3.6          None         None       None
#
#   interestCoverage netDebtEBITDA
# 0             None          None

# %%
financial_health_rating("MBB")
# Out:
#   industryEn  loanDeposit  badLoanGrossLoan  badLoanAsset  provisionBadLoan  \
# 0      Banks            1                 4             4                 5
#
#   ticker  financialHealth netDebtEquity currentRatio quickRatio  \
# 0    MBB              3.4          None         None       None
#
#   interestCoverage netDebtEBITDA
# 0             None          None

# %%
financial_health_rating("VIX")
# Out:
#             industryEn loanDeposit badLoanGrossLoan badLoanAsset  \
# 0  Investment Services        None             None         None
#
#   provisionBadLoan ticker  financialHealth  netDebtEquity  currentRatio  \
# 0             None    VIX              4.2              5             5
#
#    quickRatio  interestCoverage  netDebtEBITDA
# 0           5                 1              5

# %%
financial_health_rating("GMD")
# Out:
#                 industryEn loanDeposit badLoanGrossLoan badLoanAsset  \
# 0  Transportation Services        None             None         None
#
#   provisionBadLoan ticker  financialHealth  netDebtEquity  currentRatio  \
# 0             None    GMD              4.6              4             4
#
#    quickRatio  interestCoverage  netDebtEBITDA
# 0           5                 5              5

# %%
fr_trade_heatmap ('ACB', 'FrBuyVol')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# General rating

# %%
general_rating("ACB")
# Out:
#    stockRating  valuation  financialHealth  businessModel  businessOperation  \
# 0          3.1        3.3              3.6            3.6                4.3
#
#    rsRating  taScore ticker  highestPrice  lowestPrice  priceChange3m  \
# 0       2.8      1.0    ACB       28500.0      20172.5          0.075
#
#    priceChange1y  beta   alpha
# 0          0.303  0.81  0.0007

# %%
general_rating("MBB")
# Out:
#    stockRating  valuation  financialHealth  businessModel  businessOperation  \
# 0          3.4        3.1              3.4            4.5                4.7
#
#    rsRating  taScore ticker  highestPrice  lowestPrice  priceChange3m  \
# 0       3.5      1.0    MBB       25500.0      15310.2           0.15
#
#    priceChange1y  beta  alpha
# 0          0.493  0.97  0.001

# %%
general_rating("VIX")
# Out:
#    stockRating  valuation  financialHealth  businessModel  businessOperation  \
# 0          3.1        2.0              4.2            3.0                4.7
#
#    rsRating  taScore ticker  highestPrice  lowestPrice  priceChange3m  \
# 0       3.6      1.0    VIX       21000.0       6522.0          0.113
#
#    priceChange1y  beta   alpha
# 0          1.653  2.09  0.0019

# %%
general_rating("GMD")
# Out:
#    stockRating  valuation  financialHealth  businessModel  businessOperation  \
# 0          3.2        2.0              4.6            4.4                3.7
#
#    rsRating  taScore ticker  highestPrice  lowestPrice  priceChange3m  \
# 0       3.6      1.0    GMD       80600.0      47612.3          0.109
#
#    priceChange1y  beta   alpha
# 0          0.543   1.1  0.0016

# %% [markdown]
# BUSINESS MODEL RATING

# %%
biz_model_rating("ACB")
# Out:
#   ticker  businessModel  businessEfficiency  assetQuality  cashFlowQuality  \
# 0    ACB            3.6                   4             4                4
#
#    bom  businessAdministration  productService  businessAdvantage  \
# 0    4                       4               4                  4
#
#    companyPosition  industry  operationRisk
# 0                4         4              4

# %%
biz_model_rating("GMD")
# Out:
#   ticker  businessModel  businessEfficiency  assetQuality  cashFlowQuality  \
# 0    GMD            4.4                   4             4                5
#
#    bom  businessAdministration  productService  businessAdvantage  \
# 0    4                       4               5                  4
#
#    companyPosition  industry  operationRisk
# 0                5         5              5

# %%
biz_model_rating("VIX")
# Out:
#   ticker  businessModel  businessEfficiency  assetQuality  cashFlowQuality  \
# 0    VIX            3.0                   3             3                3
#
#    bom  businessAdministration  productService  businessAdvantage  \
# 0    3                       3               3                  3
#
#    companyPosition  industry  operationRisk
# 0                3         3              3

# %%
biz_model_rating("MBB")
# Out:
#   ticker  businessModel  businessEfficiency  assetQuality  cashFlowQuality  \
# 0    MBB            4.5                   5             4                5
#
#    bom  businessAdministration  productService  businessAdvantage  \
# 0    5                       5               5                  5
#
#    companyPosition  industry  operationRisk
# 0                5         3              3

# %% [markdown]
# BUSINESS OPERATION RATING

# %%
biz_operation_rating("ACB")
# Out:
#   industryEn  loanGrowth  depositGrowth  netInterestIncomeGrowth  \
# 0      Banks           4              3                        4
#
#    netInterestMargin  costToIncome  netIncomeTOI ticker  businessOperation  \
# 0                  3             5             5    ACB                4.3
#
#    avgROE  avgROA  last5yearsNetProfitGrowth last5yearsRevenueGrowth  \
# 0       5       5                          5                    None
#
#   last5yearsOperatingProfitGrowth last5yearsEBITDAGrowth last5yearsFCFFGrowth  \
# 0                            None                   None                 None
#
#   lastYearGrossProfitMargin lastYearOperatingProfitMargin  \
# 0                      None                          None
#
#   lastYearNetProfitMargin  TOIGrowth
# 0                    None          4

# %%
biz_operation_rating("VIX")
# Out:
#             industryEn loanGrowth depositGrowth netInterestIncomeGrowth  \
# 0  Investment Services       None          None                    None
#
#   netInterestMargin costToIncome netIncomeTOI ticker  businessOperation  \
# 0              None         None         None    VIX                4.7
#
#    avgROE  avgROA  last5yearsNetProfitGrowth  last5yearsRevenueGrowth  \
# 0       3       4                          5                        5
#
#    last5yearsOperatingProfitGrowth  last5yearsEBITDAGrowth  \
# 0                                5                       5
#
#    last5yearsFCFFGrowth  lastYearGrossProfitMargin  \
# 0                     5                          5
#
#    lastYearOperatingProfitMargin  lastYearNetProfitMargin TOIGrowth
# 0                              5                        5      None

# %%
biz_operation_rating("GMD")
# Out:
#                 industryEn loanGrowth depositGrowth netInterestIncomeGrowth  \
# 0  Transportation Services       None          None                    None
#
#   netInterestMargin costToIncome netIncomeTOI ticker  businessOperation  \
# 0              None         None         None    GMD                3.7
#
#    avgROE  avgROA  last5yearsNetProfitGrowth  last5yearsRevenueGrowth  \
# 0       5       5                          2                        2
#
#    last5yearsOperatingProfitGrowth  last5yearsEBITDAGrowth  \
# 0                                4                       3
#
#    last5yearsFCFFGrowth  lastYearGrossProfitMargin  \
# 0                     2                          5
#
#    lastYearOperatingProfitMargin  lastYearNetProfitMargin TOIGrowth
# 0                              4                        5      None

# %%
biz_operation_rating("MBB")
# Out:
#   industryEn  loanGrowth  depositGrowth  netInterestIncomeGrowth  \
# 0      Banks           5              4                        5
#
#    netInterestMargin  costToIncome  netIncomeTOI ticker  businessOperation  \
# 0                  4             5             5    MBB                4.7
#
#    avgROE  avgROA  last5yearsNetProfitGrowth last5yearsRevenueGrowth  \
# 0       5       5                          5                    None
#
#   last5yearsOperatingProfitGrowth last5yearsEBITDAGrowth last5yearsFCFFGrowth  \
# 0                            None                   None                 None
#
#   lastYearGrossProfitMargin lastYearOperatingProfitMargin  \
# 0                      None                          None
#
#   lastYearNetProfitMargin  TOIGrowth
# 0                    None          4

# %% [markdown]
# VALUATION RATNG

# %%
valuation_rating("ACB")
# Out:
#   industryEn ticker  valuation  pe  pb    ps evebitda  dividendRate
# 0      Banks    ACB        3.3   4   3  None     None             3

# %%
valuation_rating("GMD")
# Out:
#                 industryEn ticker  valuation  pe  pb  ps  evebitda  \
# 0  Transportation Services    GMD        2.0   3   2   1         1
#
#    dividendRate
# 0             3

# %%
valuation_rating("VIX")
# Out:
#             industryEn ticker  valuation  pe  pb  ps  evebitda  dividendRate
# 0  Investment Services    VIX        2.0   2   3   1         2             1

# %%
valuation_rating("MBB")
# Out:
#   industryEn ticker  valuation  pe  pb    ps evebitda  dividendRate
# 0      Banks    MBB        3.1   4   3  None     None             2
